# %%
import pandas as pd
import seaborn as seaborn
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("agora.csv - agora.csv.csv")

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x = df.drop('Profit', axis= 1 )

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y = df.Profit

# %%
y. head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %% [markdown]
# # Mapping function; source : Online |

# %%
mapping = { 'Dhaka' : 1, 'Ctg': 2, 'Rangpur': 3}
df["Area"] = df["Area"]. map(mapping)

# %%
df. head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %% [markdown]
# # Scaling

# %%
# Min-Max Scaling

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df. head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %%
 #df["Marketing Spend"] = scaler. fit_transform(x[["Marketing Spend"]])

# %%
df. head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %%
# Standard Scaler
df2= pd.read_csv("agora.csv - agora.csv.csv")
from sklearn.preprocessing import StandardScaler
scaler2 = StandardScaler()
df. head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     3  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     3  166187.94

# %%
# df['Administration']= scaler2. fit_transform(x[['Administration']])
df. head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61        0.560753  471784.10     1  192261.83
# 1        162597.70        1.082807  443898.53     2  191792.06
# 2        153441.51       -0.728257  407934.54     3  191050.39
# 3        144372.41       -0.096365  383199.62     1  182901.99
# 4        142107.34       -1.079919  366168.42     3  166187.94

# %%
# Robust Scaler
df3= pd.read_csv("agora.csv - agora.csv.csv")
from sklearn.preprocessing import RobustScaler
scaler3 = RobustScaler()
df3. head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df3["Transport"] = scaler3. fit_transform(x[["Transport"]])
df3. head()

# %%
 #MaxAbsScaler
df4= pd.read_csv("agora.csv - agora.csv.csv")
from sklearn.preprocessing import MaxAbsScaler
scaler4 = MaxAbsScaler()
df4. head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df4["Transport"] = scaler3. fit_transform(x[["Transport"]])
df4. head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80   1.552016    Dhaka  192261.83
# 1        162597.70       151377.59   1.383714      Ctg  191792.06
# 2        153441.51       101145.55   1.166654  Rangpur  191050.39
# 3        144372.41       118671.85   1.017368    Dhaka  182901.99
# 4        142107.34        91391.77   0.914576  Rangpur  166187.94
